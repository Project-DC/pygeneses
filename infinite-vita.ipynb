# %%
from pygeneses.envs.prima_vita import PrimaVita
# Out:
# pygame 2.0.0.dev10 (SDL 2.0.12, python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
params_dic = {"initial_population": 1, "max_age": 40000, "model_updates": 40, "state_size": 9,
              "sensory_radius": 100}

# %%
model = PrimaVita(params_dic=params_dic, log_dir_info="inf", mode="human")

# %%
model.run()
# Out:
# 6
# Time step: 0, action: Move south-west
# 6
# Time step: 1, action: Move south-west
# 6
# Time step: 2, action: Move south-west
# 6
# Time step: 3, action: Move south-west
# 6
# Time step: 4, action: Move south-west
# 6
# Time step: 5, action: Move south-west
# Explore krna hi padega tereko!
# 6
# Time step: 6, action: Move south-west
# Explore krna hi padega tereko!
# 6
# Time step: 7, action: Move south-west
# Explore krna hi padega tereko!
# 6
# Time step: 8, action: Move south-west
# Explore krna hi padega tereko!
# 6
# Time step: 9, action: Move south-west
# Explore krna hi padega tereko!
# 6
# Time step: 10, action: Move south-west
# Explore krna hi padega tereko!
# 9
# Time step: 11, action: Fight
# 9
# Time step: 12, action: Fight
# 9
# Time step: 13, action: Fight
# Explore krna hi padega tereko!
# 9
# Time step: 14, action: Fight
# Explore krna hi padega tereko!
# 9
# Time step: 15, action: Fight
# Explore krna hi padega tereko!
# 9
# Time step: 16, action: Fight
# ...
