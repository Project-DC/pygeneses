# %%
from pygeneses.envs.prima_vita import PrimaVita
# Out:
# pygame 2.0.0.dev10 (SDL 2.0.12, python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
model = PrimaVita(log_dir_info="test_state_10k")

# %%
model.run(stop_at=10000)
# Out:
# RIP 0-4, alive count = 10
# RIP 21-15, alive count = 15
# RIP 0-1, alive count = 19
# RIP 21-12, alive count = 26
# RIP 42-19, alive count = 29
# RIP 21-14, alive count = 35
# RIP 44-28, alive count = 37
# RIP 44-23, alive count = 39
# RIP 52-29, alive count = 44
# RIP 52-30, alive count = 45
# RIP 52-31, alive count = 52
# RIP 52-35, alive count = 56
# RIP 52-39, alive count = 62
# RIP 54-45, alive count = 69
# RIP 54-44, alive count = 70
# RIP 60-49, alive count = 77
# RIP 62-56, alive count = 84
# RIP 62-63, alive count = 91
# RIP 62-65, alive count = 98
# RIP 62-66, alive count = 99
# Max population exceeded! Number of people to be killed: 6
# RIP 0-2, alive count = 105
# RIP 72-105, alive count = 104
# RIP 62-62, alive count = 103
# RIP 21-10, alive count = 102
# RIP 69-88, alive count = 101
# RIP 69-89, alive count = 100
# RIP 62-68, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 62-57, alive count = 106
# RIP 62-78, alive count = 105
# ...
