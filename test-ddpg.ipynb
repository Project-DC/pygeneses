# %%
from pygeneses.envs.prima_vita import PrimaVita
# Out:
# pygame 2.0.0 (SDL 2.0.12, python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
params_dic = {"initial_population": 30, "state_size": 32, "speed": 10}

model = PrimaVita(mode="bot", log_dir_info="ddpg_more_punish", params_dic=params_dic)

# %%
model.run(stop_at=10000)
# Out:
# Asexual reproduction
# RIP 0-13, died at age 10, alive count = 30
# Asexual reproduction
# RIP 0-20, died at age 10, alive count = 37
# Asexual reproduction
# RIP 0-10, died at age 11, alive count = 44
# Asexual reproduction
# RIP 0-2, died at age 13, alive count = 51
# Asexual reproduction
# RIP 0-8, died at age 15, alive count = 58
# Asexual reproduction
# RIP 10-33, died at age 10, alive count = 65
# Asexual reproduction
# RIP 10-35, died at age 10, alive count = 68
# Asexual reproduction
# RIP 10-36, died at age 10, alive count = 75
# Asexual reproduction
# RIP 10-37, died at age 10, alive count = 82
# Asexual reproduction
# RIP 10-32, died at age 11, alive count = 89
# Asexual reproduction
# RIP 10-34, died at age 11, alive count = 96
# Max population exceeded! Number of people to be killed: 3
# RIP 13-60, died at age 8, alive count = 102
# RIP 21-109, died at age 0, alive count = 101
# RIP 15-65, died at age 6, alive count = 100
# Asexual reproduction
# ...

# %%
from pygeneses.envs.prima_vita.env import save

save(model, "ddpg_test_more_punish")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-88e9265de812> in <module>
#       1 from pygeneses.envs.prima_vita.env import save
#       2
# ----> 3 save(model, "ddpg_test_more_punish")
#
# D:\oss\project-dc\pygeneses\pygeneses\envs\prima_vita\env.py in save(model, filename)
#      40     # Dump into pickle file
#      41     with open(filename, "wb") as file:
# ---> 42         pickle.dump(model, file)
#      43
#      44     print(f"Prima vita environment snapshot created successfully at {filename}!")
#
# TypeError: cannot pickle 'torch._C.Generator' object
