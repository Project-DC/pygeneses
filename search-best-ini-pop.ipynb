# %%
from pygeneses.envs.prima_vita import PrimaVita
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
initial_populations = [5, 10, 20, 50, 80, 100]

for initial_population in initial_populations:
    print("-" * 100)
    print("Initial population:", initial_population)
    print("-" * 100)
    model = PrimaVita(initial_population=initial_population, log_dir_info="ini_pop_" + str(initial_population))
    model.run(stop_at=2000)
# Out:
# ----------------------------------------------------------------------------------------------------
# Initial population: 5
# ----------------------------------------------------------------------------------------------------
# RIP 0-0, alive count = 5
# RIP 0-3, alive count = 4
# RIP 20-7, alive count = 9
# RIP 0-4, alive count = 14
# RIP 0-2, alive count = 13
# RIP 0-1, alive count = 12
# RIP 20-8, alive count = 11
# RIP 20-10, alive count = 10
# RIP 30-16, alive count = 9
# RIP 20-5, alive count = 8
# RIP 20-6, alive count = 8
# RIP 20-9, alive count = 8
# RIP 30-11, alive count = 5
# RIP 30-12, alive count = 5
# RIP 30-13, alive count = 5
# RIP 30-14, alive count = 5
# RIP 30-15, alive count = 5
# ----------------------------------------------------------------------------------------------------
# Initial population: 10
# ----------------------------------------------------------------------------------------------------
# RIP 0-6, alive count = 10
# RIP 10-10, alive count = 12
# RIP 10-12, alive count = 18
# RIP 20-17, alive count = 22
# RIP 20-18, alive count = 24
# RIP 20-20, alive count = 29
# RIP 20-23, alive count = 34
# RIP 20-24, alive count = 40
# RIP 0-0, alive count = 42
# RIP 0-4, alive count = 41
# RIP 0-7, alive count = 40
# RIP 30-27, alive count = 39
# RIP 30-29, alive count = 40
# RIP 30-30, alive count = 46
# RIP 30-32, alive count = 52
# RIP 30-33, alive count = 56
# RIP 30-36, alive count = 57
# RIP 30-37, alive count = 62
# RIP 30-38, alive count = 69
# RIP 30-39, alive count = 72
# RIP 30-41, alive count = 78
# RIP 30-42, alive count = 85
# RIP 30-43, alive count = 90
# RIP 30-46, alive count = 92
# RIP 0-9, alive count = 98
# RIP 0-5, alive count = 97
# RIP 40-51, alive count = 96
# RIP 40-53, alive count = 97
# Max population exceeded! Number of people to be killed: 3
# RIP 50-126, alive count = 102
# RIP 40-121, alive count = 101
# RIP 30-40, alive count = 100
# RIP 40-54, alive count = 100
# /Users/siddhartha.choudhury/Documents/work/projects/project-dc/pygeneses/pygeneses/envs/prima_vita/player_class.py:153: RuntimeWarning: invalid value encountered in true_divide
#   self.embeddings = self.embeddings / (time - self.born_at)
# Max population exceeded! Number of people to be killed: 5
# RIP 40-71, alive count = 104
# RIP 30-34, alive count = 103
# RIP 40-73, alive count = 102
# RIP 40-106, alive count = 101
# RIP 40-70, alive count = 100
# RIP 40-55, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 30-35, alive count = 106
# RIP 40-66, alive count = 105
# RIP 40-109, alive count = 104
# RIP 40-76, alive count = 103
# RIP 40-117, alive count = 102
# RIP 50-132, alive count = 101
# RIP 40-89, alive count = 100
# RIP 40-57, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 50-144, alive count = 102
# RIP 40-75, alive count = 101
# RIP 40-108, alive count = 100
# RIP 40-58, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 20-19, alive count = 100
# RIP 40-60, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 40-95, alive count = 100
# RIP 40-63, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 50-140, alive count = 102
# RIP 40-81, alive count = 101
# RIP 40-62, alive count = 100
# RIP 40-65, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 50-142, alive count = 105
# RIP 50-159, alive count = 104
# RIP 40-67, alive count = 103
# RIP 50-157, alive count = 102
# RIP 40-97, alive count = 101
# RIP 30-47, alive count = 100
# RIP 40-69, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 20-15, alive count = 103
# RIP 20-22, alive count = 102
# RIP 40-94, alive count = 101
# RIP 40-56, alive count = 100
# RIP 40-72, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 40-115, alive count = 105
# RIP 40-90, alive count = 104
# RIP 50-129, alive count = 103
# RIP 50-160, alive count = 102
# RIP 50-161, alive count = 101
# RIP 40-102, alive count = 100
# RIP 40-74, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 40-68, alive count = 106
# RIP 50-171, alive count = 105
# RIP 50-130, alive count = 104
# RIP 50-137, alive count = 103
# RIP 40-105, alive count = 102
# RIP 50-183, alive count = 101
# RIP 50-127, alive count = 100
# RIP 40-82, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 10-11, alive count = 101
# RIP 40-119, alive count = 100
# RIP 40-83, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 40-59, alive count = 105
# RIP 50-188, alive count = 104
# RIP 50-139, alive count = 103
# RIP 40-50, alive count = 102
# RIP 40-96, alive count = 101
# RIP 30-49, alive count = 100
# RIP 40-84, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 30-31, alive count = 101
# RIP 50-134, alive count = 100
# RIP 40-85, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 40-78, alive count = 102
# RIP 40-64, alive count = 101
# RIP 40-118, alive count = 100
# RIP 40-87, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 40-103, alive count = 106
# RIP 50-203, alive count = 105
# RIP 50-184, alive count = 104
# RIP 50-185, alive count = 103
# RIP 40-116, alive count = 102
# RIP 50-176, alive count = 101
# RIP 50-147, alive count = 100
# RIP 40-88, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 50-191, alive count = 100
# RIP 40-93, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 40-110, alive count = 104
# RIP 40-101, alive count = 103
# RIP 40-113, alive count = 102
# RIP 50-167, alive count = 101
# RIP 50-200, alive count = 100
# RIP 40-98, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 30-48, alive count = 101
# RIP 50-145, alive count = 100
# RIP 40-104, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 50-187, alive count = 104
# RIP 50-182, alive count = 103
# RIP 50-143, alive count = 102
# RIP 50-125, alive count = 101
# RIP 50-207, alive count = 100
# RIP 40-107, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 50-178, alive count = 105
# RIP 50-179, alive count = 104
# RIP 50-149, alive count = 103
# RIP 50-152, alive count = 102
# RIP 40-91, alive count = 101
# RIP 40-114, alive count = 100
# RIP 20-14, alive count = 100
# RIP 30-44, alive count = 99
# RIP 50-123, alive count = 98
# Max population exceeded! Number of people to be killed: 5
# RIP 50-225, alive count = 104
# RIP 50-128, alive count = 103
# RIP 50-222, alive count = 102
# RIP 50-226, alive count = 101
# RIP 40-111, alive count = 100
# RIP 50-138, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 30-28, alive count = 102
# RIP 60-234, alive count = 101
# RIP 50-231, alive count = 100
# RIP 50-148, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 60-238, alive count = 104
# RIP 50-180, alive count = 103
# RIP 50-214, alive count = 102
# RIP 50-155, alive count = 101
# RIP 30-26, alive count = 100
# RIP 50-156, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 50-198, alive count = 105
# RIP 50-177, alive count = 104
# RIP 30-25, alive count = 103
# RIP 60-241, alive count = 102
# RIP 50-232, alive count = 101
# RIP 50-158, alive count = 100
# RIP 50-162, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 60-247, alive count = 104
# RIP 60-235, alive count = 103
# RIP 50-135, alive count = 102
# RIP 60-239, alive count = 101
# RIP 50-220, alive count = 100
# RIP 50-164, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 50-192, alive count = 101
# RIP 50-133, alive count = 100
# RIP 50-165, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 50-189, alive count = 100
# RIP 50-168, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 60-248, alive count = 101
# RIP 50-151, alive count = 100
# RIP 50-169, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 60-257, alive count = 102
# RIP 50-166, alive count = 101
# RIP 60-255, alive count = 100
# RIP 50-175, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 50-216, alive count = 106
# RIP 50-172, alive count = 105
# RIP 60-280, alive count = 104
# RIP 60-283, alive count = 103
# RIP 60-264, alive count = 102
# RIP 50-141, alive count = 101
# RIP 50-212, alive count = 100
# RIP 50-194, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 60-233, alive count = 105
# RIP 60-282, alive count = 104
# RIP 60-242, alive count = 103
# RIP 40-120, alive count = 102
# RIP 60-258, alive count = 101
# RIP 60-290, alive count = 100
# RIP 50-196, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 60-251, alive count = 102
# RIP 50-217, alive count = 101
# RIP 50-170, alive count = 100
# RIP 50-199, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 60-276, alive count = 106
# RIP 50-224, alive count = 105
# RIP 60-256, alive count = 104
# RIP 60-286, alive count = 103
# RIP 50-204, alive count = 102
# RIP 60-288, alive count = 101
# RIP 60-298, alive count = 100
# RIP 50-201, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 50-146, alive count = 106
# RIP 50-228, alive count = 105
# RIP 60-305, alive count = 104
# RIP 60-250, alive count = 103
# RIP 50-193, alive count = 102
# RIP 60-289, alive count = 101
# RIP 60-269, alive count = 100
# RIP 50-208, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 50-202, alive count = 103
# RIP 50-173, alive count = 102
# RIP 60-267, alive count = 101
# RIP 60-287, alive count = 100
# RIP 50-213, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 60-275, alive count = 101
# RIP 60-312, alive count = 100
# RIP 50-215, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 50-181, alive count = 104
# RIP 0-3, alive count = 103
# RIP 60-303, alive count = 102
# RIP 40-77, alive count = 101
# RIP 60-304, alive count = 100
# RIP 50-218, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 50-153, alive count = 101
# RIP 40-100, alive count = 100
# RIP 50-223, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 50-122, alive count = 103
# RIP 60-261, alive count = 102
# RIP 60-272, alive count = 101
# RIP 60-328, alive count = 100
# RIP 50-197, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 0-1, alive count = 103
# RIP 60-273, alive count = 102
# RIP 60-296, alive count = 101
# RIP 50-219, alive count = 100
# RIP 40-112, alive count = 100
# RIP 60-243, alive count = 99
# Max population exceeded! Number of people to be killed: 3
# RIP 40-99, alive count = 102
# RIP 60-321, alive count = 101
# RIP 61-335, alive count = 100
# RIP 60-244, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 50-195, alive count = 101
# RIP 60-315, alive count = 100
# RIP 60-246, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 60-268, alive count = 106
# RIP 60-307, alive count = 105
# RIP 60-330, alive count = 104
# RIP 70-340, alive count = 103
# RIP 40-79, alive count = 102
# RIP 50-186, alive count = 101
# RIP 60-292, alive count = 100
# RIP 60-252, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 60-311, alive count = 101
# RIP 70-343, alive count = 100
# RIP 60-253, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 60-331, alive count = 102
# RIP 60-245, alive count = 101
# RIP 70-360, alive count = 100
# RIP 60-254, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 60-259, alive count = 104
# RIP 60-285, alive count = 103
# RIP 60-320, alive count = 102
# RIP 40-80, alive count = 101
# RIP 70-353, alive count = 100
# RIP 60-266, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 60-249, alive count = 106
# RIP 60-236, alive count = 105
# RIP 50-210, alive count = 104
# RIP 60-314, alive count = 103
# RIP 60-281, alive count = 102
# RIP 60-293, alive count = 101
# RIP 70-345, alive count = 100
# RIP 60-271, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 70-342, alive count = 103
# RIP 70-348, alive count = 102
# RIP 50-131, alive count = 101
# RIP 60-332, alive count = 100
# RIP 60-274, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 50-124, alive count = 106
# RIP 70-377, alive count = 105
# RIP 70-339, alive count = 104
# RIP 0-8, alive count = 103
# RIP 30-45, alive count = 102
# RIP 60-302, alive count = 101
# RIP 70-359, alive count = 100
# RIP 60-284, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 70-374, alive count = 102
# RIP 70-363, alive count = 101
# RIP 60-310, alive count = 100
# RIP 60-295, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 60-277, alive count = 106
# RIP 70-370, alive count = 105
# RIP 40-61, alive count = 104
# RIP 60-313, alive count = 103
# RIP 60-291, alive count = 102
# RIP 50-150, alive count = 101
# RIP 50-230, alive count = 100
# RIP 60-297, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 0-2, alive count = 103
# RIP 60-278, alive count = 102
# RIP 70-400, alive count = 101
# RIP 70-367, alive count = 100
# RIP 60-301, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 70-392, alive count = 106
# RIP 70-358, alive count = 105
# RIP 70-350, alive count = 104
# RIP 70-338, alive count = 103
# RIP 70-409, alive count = 102
# RIP 60-240, alive count = 101
# RIP 70-365, alive count = 100
# RIP 60-308, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 70-393, alive count = 100
# RIP 60-316, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 70-354, alive count = 103
# RIP 70-419, alive count = 102
# RIP 70-361, alive count = 101
# RIP 70-379, alive count = 100
# RIP 60-317, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 70-371, alive count = 100
# RIP 60-318, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 60-306, alive count = 106
# RIP 70-416, alive count = 105
# RIP 60-326, alive count = 104
# RIP 70-386, alive count = 103
# RIP 60-279, alive count = 102
# RIP 70-378, alive count = 101
# RIP 60-309, alive count = 100
# RIP 60-327, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 40-92, alive count = 104
# RIP 60-324, alive count = 103
# RIP 61-336, alive count = 102
# RIP 70-344, alive count = 101
# RIP 40-86, alive count = 100
# RIP 60-262, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 70-422, alive count = 103
# RIP 70-402, alive count = 102
# RIP 70-423, alive count = 101
# RIP 70-418, alive count = 100
# RIP 61-333, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 70-394, alive count = 101
# RIP 60-329, alive count = 100
# RIP 61-334, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 70-382, alive count = 103
# RIP 70-387, alive count = 102
# RIP 50-221, alive count = 101
# RIP 70-399, alive count = 100
# RIP 61-337, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 70-420, alive count = 100
# RIP 70-341, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 71-443, alive count = 102
# RIP 70-405, alive count = 101
# RIP 70-414, alive count = 100
# RIP 70-346, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 71-447, alive count = 105
# RIP 70-390, alive count = 104
# RIP 70-434, alive count = 103
# RIP 70-425, alive count = 102
# RIP 70-357, alive count = 101
# RIP 70-398, alive count = 100
# RIP 70-347, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 80-460, alive count = 105
# RIP 70-369, alive count = 104
# RIP 70-375, alive count = 103
# RIP 71-449, alive count = 102
# RIP 60-319, alive count = 101
# RIP 80-463, alive count = 100
# RIP 70-352, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 71-445, alive count = 102
# RIP 70-407, alive count = 101
# RIP 71-446, alive count = 100
# RIP 70-356, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 70-430, alive count = 101
# RIP 70-433, alive count = 100
# RIP 70-364, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 80-478, alive count = 105
# RIP 70-404, alive count = 104
# RIP 80-467, alive count = 103
# RIP 80-479, alive count = 102
# RIP 80-458, alive count = 101
# RIP 70-410, alive count = 100
# RIP 70-366, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 20-13, alive count = 106
# RIP 80-459, alive count = 105
# RIP 80-471, alive count = 104
# RIP 60-300, alive count = 103
# RIP 70-395, alive count = 102
# RIP 70-396, alive count = 101
# RIP 80-484, alive count = 100
# RIP 70-368, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 80-462, alive count = 103
# RIP 71-448, alive count = 102
# RIP 80-487, alive count = 101
# RIP 60-294, alive count = 100
# RIP 70-373, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 70-412, alive count = 102
# RIP 70-349, alive count = 101
# RIP 80-496, alive count = 100
# RIP 70-383, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 70-389, alive count = 105
# RIP 71-442, alive count = 104
# RIP 70-385, alive count = 103
# RIP 70-388, alive count = 102
# RIP 60-270, alive count = 101
# RIP 80-486, alive count = 100
# RIP 70-384, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 80-452, alive count = 101
# RIP 71-450, alive count = 100
# RIP 70-391, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 80-469, alive count = 104
# RIP 80-464, alive count = 103
# RIP 80-498, alive count = 102
# RIP 80-468, alive count = 101
# RIP 70-401, alive count = 100
# RIP 70-406, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 80-475, alive count = 106
# RIP 70-362, alive count = 105
# RIP 80-511, alive count = 104
# RIP 80-522, alive count = 103
# RIP 71-444, alive count = 102
# RIP 71-437, alive count = 101
# RIP 80-456, alive count = 100
# RIP 70-415, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 50-229, alive count = 102
# RIP 80-466, alive count = 101
# RIP 60-323, alive count = 100
# RIP 70-427, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 80-519, alive count = 106
# RIP 80-470, alive count = 105
# RIP 80-525, alive count = 104
# RIP 80-507, alive count = 103
# RIP 71-438, alive count = 102
# RIP 71-440, alive count = 101
# RIP 70-421, alive count = 100
# RIP 70-428, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 80-512, alive count = 102
# RIP 80-510, alive count = 101
# RIP 80-508, alive count = 100
# RIP 71-436, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 80-494, alive count = 105
# RIP 70-424, alive count = 104
# RIP 80-485, alive count = 103
# RIP 80-536, alive count = 102
# RIP 70-417, alive count = 101
# RIP 80-457, alive count = 100
# RIP 40-52, alive count = 100
# RIP 70-411, alive count = 99
# Max population exceeded! Number of people to be killed: 6
# RIP 80-490, alive count = 105
# RIP 50-205, alive count = 104
# RIP 80-489, alive count = 103
# RIP 80-483, alive count = 102
# RIP 85-553, alive count = 101
# RIP 80-473, alive count = 100
# RIP 50-209, alive count = 100
# RIP 50-211, alive count = 99
# RIP 80-451, alive count = 98
# Max population exceeded! Number of people to be killed: 1
# RIP 80-530, alive count = 100
# RIP 80-454, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 80-493, alive count = 104
# RIP 80-524, alive count = 103
# RIP 80-521, alive count = 102
# RIP 85-549, alive count = 101
# RIP 60-322, alive count = 100
# RIP 80-461, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 81-543, alive count = 103
# RIP 81-542, alive count = 102
# RIP 50-206, alive count = 101
# RIP 80-465, alive count = 100
# RIP 80-472, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 80-505, alive count = 104
# RIP 60-265, alive count = 103
# RIP 70-403, alive count = 102
# RIP 70-381, alive count = 101
# RIP 60-299, alive count = 100
# RIP 80-476, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 80-532, alive count = 104
# RIP 90-575, alive count = 103
# RIP 90-561, alive count = 102
# RIP 85-551, alive count = 101
# RIP 50-154, alive count = 100
# RIP 80-477, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 90-574, alive count = 102
# RIP 80-495, alive count = 101
# RIP 80-499, alive count = 100
# RIP 80-482, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 80-501, alive count = 102
# RIP 71-441, alive count = 101
# RIP 90-563, alive count = 100
# RIP 80-492, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 80-531, alive count = 101
# RIP 90-569, alive count = 100
# RIP 80-497, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 70-372, alive count = 106
# RIP 80-488, alive count = 105
# RIP 50-163, alive count = 104
# RIP 71-439, alive count = 103
# RIP 81-545, alive count = 102
# RIP 90-597, alive count = 101
# RIP 90-583, alive count = 100
# RIP 80-500, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 80-509, alive count = 105
# RIP 90-555, alive count = 104
# RIP 80-506, alive count = 103
# RIP 50-174, alive count = 102
# RIP 60-260, alive count = 101
# RIP 20-16, alive count = 100
# RIP 80-504, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 70-351, alive count = 100
# RIP 80-513, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 90-602, alive count = 105
# RIP 80-517, alive count = 104
# RIP 60-263, alive count = 103
# RIP 80-453, alive count = 102
# RIP 90-608, alive count = 101
# RIP 70-355, alive count = 100
# RIP 80-518, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 90-596, alive count = 106
# RIP 90-611, alive count = 105
# RIP 90-579, alive count = 104
# RIP 80-514, alive count = 103
# RIP 90-586, alive count = 102
# RIP 90-593, alive count = 101
# RIP 70-431, alive count = 100
# RIP 80-528, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 80-481, alive count = 102
# RIP 85-548, alive count = 101
# RIP 90-594, alive count = 100
# RIP 80-533, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 80-534, alive count = 101
# RIP 80-515, alive count = 100
# RIP 80-535, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 90-567, alive count = 100
# RIP 80-538, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 90-638, alive count = 105
# RIP 90-595, alive count = 104
# RIP 90-620, alive count = 103
# RIP 90-559, alive count = 102
# RIP 90-629, alive count = 101
# RIP 81-544, alive count = 100
# RIP 80-539, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 90-621, alive count = 101
# RIP 90-606, alive count = 100
# RIP 81-540, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 90-616, alive count = 105
# RIP 90-625, alive count = 104
# RIP 90-592, alive count = 103
# RIP 90-603, alive count = 102
# RIP 70-432, alive count = 101
# RIP 90-584, alive count = 100
# RIP 81-546, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 90-626, alive count = 106
# RIP 50-136, alive count = 105
# RIP 70-426, alive count = 104
# RIP 90-588, alive count = 103
# RIP 90-610, alive count = 102
# RIP 80-523, alive count = 101
# RIP 90-605, alive count = 100
# RIP 60-325, alive count = 100
