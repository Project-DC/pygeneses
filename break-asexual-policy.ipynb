# %%
from pygeneses.envs.prima_vita import PrimaVita
# Out:
# pygame 2.0.0.dev10 (SDL 2.0.12, python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
params_dic = {"model_updates": 5, "initial_population": 10}

model = PrimaVita(log_dir_info="break_asex", params_dic=params_dic)

# %%
model.run(stop_at=6000)
# Out:
# RIP 0-3, alive count = 10
# RIP 10-11, alive count = 14
# RIP 10-13, alive count = 21
# RIP 10-14, alive count = 25
# RIP 20-16, alive count = 31
# RIP 20-17, alive count = 34
# RIP 20-19, alive count = 36
# RIP 20-22, alive count = 42
# RIP 20-23, alive count = 44
# RIP 20-24, alive count = 45
# RIP 20-25, alive count = 47
# RIP 20-26, alive count = 48
# RIP 20-27, alive count = 55
# RIP 20-30, alive count = 59
# RIP 30-35, alive count = 60
# RIP 30-42, alive count = 66
# RIP 30-43, alive count = 67
# RIP 30-45, alive count = 68
# RIP 30-47, alive count = 71
# RIP 30-49, alive count = 78
# RIP 30-51, alive count = 84
# RIP 30-53, alive count = 91
# RIP 30-54, alive count = 94
# RIP 30-58, alive count = 99
# Max population exceeded! Number of people to be killed: 3
# RIP 30-71, alive count = 102
# RIP 40-123, alive count = 101
# RIP 40-122, alive count = 100
# RIP 30-60, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 0-8, alive count = 103
# RIP 30-61, alive count = 102
# RIP 20-28, alive count = 101
# RIP 40-89, alive count = 100
# RIP 30-62, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 40-75, alive count = 100
# RIP 30-63, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 40-93, alive count = 104
# RIP 40-87, alive count = 103
# RIP 30-46, alive count = 102
# RIP 0-2, alive count = 101
# RIP 30-37, alive count = 100
# RIP 30-64, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 40-95, alive count = 105
# RIP 20-34, alive count = 104
# RIP 40-133, alive count = 103
# RIP 40-76, alive count = 102
# RIP 40-102, alive count = 101
# RIP 20-32, alive count = 100
# RIP 30-65, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 20-31, alive count = 106
# RIP 40-74, alive count = 105
# RIP 20-20, alive count = 104
# RIP 40-125, alive count = 103
# RIP 40-145, alive count = 102
# RIP 40-109, alive count = 101
# RIP 40-138, alive count = 100
# RIP 30-67, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 40-118, alive count = 104
# RIP 30-56, alive count = 103
# RIP 30-36, alive count = 102
# RIP 40-131, alive count = 101
# RIP 40-78, alive count = 100
# RIP 30-68, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 30-52, alive count = 105
# RIP 40-132, alive count = 104
# RIP 40-135, alive count = 103
# RIP 40-161, alive count = 102
# RIP 40-84, alive count = 101
# RIP 0-9, alive count = 100
# RIP 30-69, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 40-158, alive count = 100
# RIP 30-73, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 30-50, alive count = 105
# RIP 0-7, alive count = 104
# RIP 40-146, alive count = 103
# RIP 40-142, alive count = 102
# RIP 40-166, alive count = 101
# RIP 40-154, alive count = 100
# RIP 30-40, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 40-150, alive count = 102
# RIP 40-162, alive count = 101
# RIP 40-97, alive count = 100
# RIP 30-70, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 40-94, alive count = 100
# RIP 20-33, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 40-116, alive count = 106
# RIP 40-86, alive count = 105
# RIP 40-117, alive count = 104
# RIP 40-165, alive count = 103
# RIP 0-0, alive count = 102
# RIP 40-155, alive count = 101
# RIP 40-111, alive count = 100
# RIP 40-79, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 50-191, alive count = 106
# RIP 40-115, alive count = 105
# RIP 50-185, alive count = 104
# RIP 41-178, alive count = 103
# RIP 20-29, alive count = 102
# RIP 50-186, alive count = 101
# RIP 40-172, alive count = 100
# RIP 40-80, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 40-156, alive count = 100
# RIP 40-81, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 40-164, alive count = 104
# RIP 50-199, alive count = 103
# RIP 50-205, alive count = 102
# RIP 43-182, alive count = 101
# RIP 40-96, alive count = 100
# RIP 40-106, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 40-124, alive count = 100
# RIP 40-108, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 40-140, alive count = 103
# RIP 50-190, alive count = 102
# RIP 40-176, alive count = 101
# RIP 41-177, alive count = 100
# RIP 40-130, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 0-5, alive count = 101
# RIP 10-12, alive count = 100
# RIP 40-134, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 50-206, alive count = 104
# RIP 50-200, alive count = 103
# RIP 40-113, alive count = 102
# RIP 40-107, alive count = 101
# RIP 50-198, alive count = 100
# RIP 40-136, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 40-129, alive count = 105
# RIP 40-100, alive count = 104
# RIP 40-128, alive count = 103
# RIP 50-217, alive count = 102
# RIP 30-72, alive count = 101
# RIP 40-139, alive count = 100
# RIP 40-137, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 50-187, alive count = 102
# RIP 50-233, alive count = 101
# RIP 30-57, alive count = 100
# RIP 40-143, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 50-192, alive count = 102
# RIP 50-213, alive count = 101
# RIP 40-83, alive count = 100
# RIP 40-149, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 30-39, alive count = 105
# RIP 40-174, alive count = 104
# RIP 40-101, alive count = 103
# RIP 30-38, alive count = 102
# RIP 10-10, alive count = 101
# RIP 50-196, alive count = 100
# RIP 40-152, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 50-238, alive count = 106
# RIP 50-237, alive count = 105
# RIP 50-218, alive count = 104
# RIP 50-224, alive count = 103
# RIP 50-216, alive count = 102
# RIP 50-201, alive count = 101
# RIP 50-240, alive count = 100
# RIP 40-157, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 50-255, alive count = 106
# RIP 50-222, alive count = 105
# RIP 40-126, alive count = 104
# RIP 50-256, alive count = 103
# RIP 50-243, alive count = 102
# RIP 40-121, alive count = 101
# RIP 50-248, alive count = 100
# RIP 40-163, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 40-148, alive count = 100
# RIP 40-171, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 50-239, alive count = 102
# RIP 40-160, alive count = 101
# RIP 50-230, alive count = 100
# RIP 40-173, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 40-151, alive count = 100
# RIP 41-179, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 40-112, alive count = 104
# RIP 40-167, alive count = 103
# RIP 50-242, alive count = 102
# RIP 50-220, alive count = 101
# RIP 50-183, alive count = 100
# RIP 40-91, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 50-253, alive count = 102
# RIP 50-223, alive count = 101
# RIP 51-274, alive count = 100
# RIP 40-92, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 50-244, alive count = 102
# RIP 50-261, alive count = 101
# RIP 20-21, alive count = 100
# RIP 40-170, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 50-188, alive count = 105
# RIP 40-85, alive count = 104
# RIP 50-252, alive count = 103
# RIP 50-257, alive count = 102
# RIP 50-202, alive count = 101
# RIP 0-6, alive count = 100
# RIP 43-181, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 40-153, alive count = 105
# RIP 52-285, alive count = 104
# RIP 50-267, alive count = 103
# RIP 40-169, alive count = 102
# RIP 50-251, alive count = 101
# RIP 52-281, alive count = 100
# RIP 50-194, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 50-203, alive count = 106
# RIP 40-144, alive count = 105
# RIP 60-298, alive count = 104
# RIP 52-282, alive count = 103
# RIP 40-119, alive count = 102
# RIP 40-127, alive count = 101
# RIP 40-110, alive count = 100
# RIP 50-215, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 0-4, alive count = 103
# RIP 50-207, alive count = 102
# RIP 50-225, alive count = 101
# RIP 30-55, alive count = 100
# RIP 50-221, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 60-301, alive count = 103
# RIP 60-308, alive count = 102
# RIP 50-265, alive count = 101
# RIP 50-268, alive count = 100
# RIP 50-227, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 60-305, alive count = 101
# RIP 40-120, alive count = 100
# RIP 50-245, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 50-208, alive count = 104
# RIP 40-82, alive count = 103
# RIP 53-291, alive count = 102
# RIP 51-269, alive count = 101
# RIP 0-1, alive count = 100
# RIP 50-246, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 30-41, alive count = 106
# RIP 20-18, alive count = 105
# RIP 50-259, alive count = 104
# RIP 60-327, alive count = 103
# RIP 50-228, alive count = 102
# RIP 50-209, alive count = 101
# RIP 40-77, alive count = 100
# RIP 50-250, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 40-159, alive count = 103
# RIP 30-59, alive count = 102
# RIP 53-292, alive count = 101
# RIP 50-247, alive count = 100
# RIP 50-254, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 50-219, alive count = 102
# RIP 50-231, alive count = 101
# RIP 52-284, alive count = 100
# RIP 50-264, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 52-289, alive count = 100
# RIP 50-235, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 60-302, alive count = 106
# RIP 40-104, alive count = 105
# RIP 50-195, alive count = 104
# RIP 60-317, alive count = 103
# RIP 40-114, alive count = 102
# RIP 50-189, alive count = 101
# RIP 61-343, alive count = 100
# RIP 52-279, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 60-310, alive count = 104
# RIP 60-338, alive count = 103
# RIP 60-332, alive count = 102
# RIP 60-299, alive count = 101
# RIP 60-325, alive count = 100
# RIP 52-283, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 53-295, alive count = 101
# RIP 60-321, alive count = 100
# RIP 52-286, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 50-184, alive count = 103
# RIP 51-270, alive count = 102
# RIP 50-236, alive count = 101
# RIP 62-359, alive count = 100
# RIP 52-288, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 50-241, alive count = 101
# RIP 52-278, alive count = 100
# RIP 53-294, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 62-365, alive count = 103
# RIP 40-98, alive count = 102
# RIP 50-211, alive count = 101
# RIP 40-168, alive count = 100
# RIP 50-263, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 52-276, alive count = 103
# RIP 62-363, alive count = 102
# RIP 50-266, alive count = 101
# RIP 50-258, alive count = 100
# RIP 60-312, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 62-360, alive count = 104
# RIP 60-333, alive count = 103
# RIP 62-364, alive count = 102
# RIP 60-341, alive count = 101
# RIP 60-322, alive count = 100
# RIP 60-319, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 50-214, alive count = 103
# RIP 70-380, alive count = 102
# RIP 64-377, alive count = 101
# RIP 61-347, alive count = 100
# RIP 60-329, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 50-229, alive count = 106
# RIP 60-330, alive count = 105
# RIP 52-275, alive count = 104
# RIP 60-335, alive count = 103
# RIP 60-303, alive count = 102
# RIP 70-389, alive count = 101
# RIP 62-366, alive count = 100
# RIP 60-334, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 60-300, alive count = 100
# RIP 60-337, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 70-383, alive count = 102
# RIP 50-197, alive count = 101
# RIP 50-232, alive count = 100
# RIP 60-342, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 60-323, alive count = 100
# RIP 60-304, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 64-374, alive count = 104
# RIP 62-352, alive count = 103
# RIP 70-404, alive count = 102
# RIP 60-318, alive count = 101
# RIP 60-315, alive count = 100
# RIP 60-331, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 50-210, alive count = 103
# RIP 60-324, alive count = 102
# RIP 60-297, alive count = 101
# RIP 20-15, alive count = 100
# RIP 61-346, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 40-99, alive count = 106
# RIP 63-369, alive count = 105
# RIP 30-48, alive count = 104
# RIP 70-379, alive count = 103
# RIP 70-388, alive count = 102
# RIP 71-422, alive count = 101
# RIP 61-345, alive count = 100
# RIP 61-350, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 60-336, alive count = 102
# RIP 71-423, alive count = 101
# RIP 70-390, alive count = 100
# RIP 60-306, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 62-357, alive count = 106
# RIP 40-147, alive count = 105
# RIP 71-425, alive count = 104
# RIP 62-362, alive count = 103
# RIP 50-226, alive count = 102
# RIP 61-348, alive count = 101
# RIP 53-293, alive count = 100
# RIP 50-262, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 71-421, alive count = 104
# RIP 60-311, alive count = 103
# RIP 72-429, alive count = 102
# RIP 70-395, alive count = 101
# RIP 62-351, alive count = 100
# RIP 52-280, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 52-287, alive count = 102
# RIP 72-435, alive count = 101
# RIP 70-384, alive count = 100
# RIP 63-370, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 70-393, alive count = 102
# RIP 71-405, alive count = 101
# RIP 62-356, alive count = 100
# RIP 63-372, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 70-401, alive count = 106
# RIP 73-452, alive count = 105
# RIP 62-361, alive count = 104
# RIP 73-455, alive count = 103
# RIP 71-416, alive count = 102
# RIP 60-313, alive count = 101
# RIP 70-402, alive count = 100
# RIP 60-326, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 70-397, alive count = 104
# RIP 72-431, alive count = 103
# RIP 60-328, alive count = 102
# RIP 71-417, alive count = 101
# RIP 71-412, alive count = 100
# RIP 63-371, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 74-466, alive count = 106
# RIP 74-469, alive count = 105
# RIP 52-277, alive count = 104
# RIP 73-442, alive count = 103
# RIP 73-449, alive count = 102
# RIP 62-355, alive count = 101
# RIP 73-447, alive count = 100
# RIP 64-373, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 74-462, alive count = 100
# RIP 64-375, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 73-446, alive count = 103
# RIP 40-103, alive count = 102
# RIP 50-204, alive count = 101
# RIP 70-381, alive count = 100
# RIP 62-353, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 30-66, alive count = 105
# RIP 30-44, alive count = 104
# RIP 74-473, alive count = 103
# RIP 53-290, alive count = 102
# RIP 78-484, alive count = 101
# RIP 62-358, alive count = 100
# RIP 70-378, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 60-320, alive count = 101
# RIP 50-193, alive count = 100
# RIP 70-382, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 74-472, alive count = 105
# RIP 60-339, alive count = 104
# RIP 80-489, alive count = 103
# RIP 40-141, alive count = 102
# RIP 71-406, alive count = 101
# RIP 60-309, alive count = 100
# RIP 70-400, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 62-367, alive count = 101
# RIP 74-459, alive count = 100
# RIP 72-433, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 50-234, alive count = 105
# RIP 80-487, alive count = 104
# RIP 73-443, alive count = 103
# RIP 50-249, alive count = 102
# RIP 60-314, alive count = 101
# RIP 78-482, alive count = 100
# RIP 73-441, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 41-180, alive count = 102
# RIP 60-340, alive count = 101
# RIP 62-354, alive count = 100
# RIP 73-448, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 51-272, alive count = 100
# RIP 73-450, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 83-514, alive count = 103
# RIP 74-467, alive count = 102
# RIP 74-460, alive count = 101
# RIP 71-411, alive count = 100
# RIP 53-296, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 50-212, alive count = 100
# RIP 70-403, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 84-525, alive count = 106
# RIP 74-463, alive count = 105
# RIP 61-344, alive count = 104
# RIP 80-493, alive count = 103
# RIP 73-454, alive count = 102
# RIP 73-439, alive count = 101
# RIP 84-517, alive count = 100
# RIP 71-418, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 70-392, alive count = 100
# RIP 74-464, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 74-461, alive count = 103
# RIP 71-424, alive count = 102
# RIP 84-529, alive count = 101
# RIP 40-90, alive count = 100
# RIP 74-470, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 84-534, alive count = 100
# RIP 70-398, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 82-504, alive count = 104
# RIP 80-496, alive count = 103
# RIP 80-488, alive count = 102
# RIP 84-519, alive count = 101
# RIP 84-533, alive count = 100
# RIP 71-426, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 78-480, alive count = 106
# RIP 78-485, alive count = 105
# RIP 70-387, alive count = 104
# RIP 63-368, alive count = 103
# RIP 73-451, alive count = 102
# RIP 74-458, alive count = 101
# RIP 84-518, alive count = 100
# RIP 71-407, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 84-521, alive count = 100
# RIP 74-468, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 85-546, alive count = 105
# RIP 80-490, alive count = 104
# RIP 86-551, alive count = 103
# RIP 84-527, alive count = 102
# RIP 85-548, alive count = 101
# RIP 72-432, alive count = 100
# RIP 70-396, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 77-478, alive count = 104
# RIP 70-399, alive count = 103
# RIP 61-349, alive count = 102
# RIP 82-503, alive count = 101
# RIP 86-556, alive count = 100
# RIP 73-456, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 84-524, alive count = 105
# RIP 85-538, alive count = 104
# RIP 87-559, alive count = 103
# RIP 84-522, alive count = 102
# RIP 84-520, alive count = 101
# RIP 73-437, alive count = 100
# RIP 77-474, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 87-574, alive count = 106
# RIP 82-500, alive count = 105
# RIP 78-481, alive count = 104
# RIP 72-434, alive count = 103
# RIP 60-316, alive count = 102
# RIP 87-579, alive count = 101
# RIP 85-544, alive count = 100
# RIP 77-477, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 84-532, alive count = 104
# RIP 84-531, alive count = 103
# RIP 85-537, alive count = 102
# RIP 80-491, alive count = 101
# RIP 85-539, alive count = 100
# RIP 80-497, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 84-530, alive count = 101
# RIP 87-569, alive count = 100
# RIP 80-498, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 90-588, alive count = 104
# RIP 87-567, alive count = 103
# RIP 80-492, alive count = 102
# RIP 71-408, alive count = 101
# RIP 83-508, alive count = 100
# RIP 71-413, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 87-563, alive count = 100
# RIP 82-499, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 92-601, alive count = 103
# RIP 40-105, alive count = 102
# RIP 82-505, alive count = 101
# RIP 87-570, alive count = 100
# RIP 83-512, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 73-445, alive count = 103
# RIP 93-603, alive count = 102
# RIP 90-594, alive count = 101
# RIP 87-573, alive count = 100
# RIP 83-513, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 87-585, alive count = 104
# RIP 73-444, alive count = 103
# RIP 83-516, alive count = 102
# RIP 86-552, alive count = 101
# RIP 84-526, alive count = 100
# RIP 84-528, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 78-479, alive count = 104
# RIP 92-596, alive count = 103
# RIP 70-386, alive count = 102
# RIP 94-616, alive count = 101
# RIP 90-587, alive count = 100
# RIP 85-542, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 93-606, alive count = 104
# RIP 94-613, alive count = 103
# RIP 83-511, alive count = 102
# RIP 87-564, alive count = 101
# RIP 85-547, alive count = 100
# RIP 85-545, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 94-618, alive count = 103
# RIP 86-558, alive count = 102
# RIP 80-494, alive count = 101
# RIP 50-260, alive count = 100
# RIP 85-549, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 87-565, alive count = 105
# RIP 71-419, alive count = 104
# RIP 82-501, alive count = 103
# RIP 94-617, alive count = 102
# RIP 71-420, alive count = 101
# RIP 86-550, alive count = 100
# RIP 87-568, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 87-571, alive count = 100
# RIP 87-576, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 83-509, alive count = 106
# RIP 87-581, alive count = 105
# RIP 95-634, alive count = 104
# RIP 95-621, alive count = 103
# RIP 72-430, alive count = 102
# RIP 70-385, alive count = 101
# RIP 73-440, alive count = 100
# RIP 87-578, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 60-307, alive count = 100
# RIP 93-607, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 86-553, alive count = 106
# RIP 103-650, alive count = 105
# RIP 98-648, alive count = 104
# RIP 103-656, alive count = 103
# RIP 97-640, alive count = 102
# RIP 87-560, alive count = 101
# RIP 71-415, alive count = 100
# RIP 93-612, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 64-376, alive count = 102
# RIP 71-410, alive count = 101
# RIP 40-88, alive count = 100
# RIP 87-584, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 95-619, alive count = 105
# RIP 95-630, alive count = 104
# RIP 95-620, alive count = 103
# RIP 70-394, alive count = 102
# RIP 71-414, alive count = 101
# RIP 95-628, alive count = 100
# RIP 94-615, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 97-645, alive count = 106
# RIP 97-646, alive count = 105
# RIP 95-623, alive count = 104
# RIP 87-580, alive count = 103
# RIP 103-657, alive count = 102
# RIP 93-605, alive count = 101
# RIP 94-614, alive count = 100
# RIP 95-635, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 93-611, alive count = 101
# RIP 78-483, alive count = 100
# RIP 95-636, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 40-175, alive count = 106
# RIP 105-678, alive count = 105
# RIP 105-681, alive count = 104
# RIP 103-654, alive count = 103
# RIP 93-609, alive count = 102
# RIP 83-515, alive count = 101
# RIP 74-471, alive count = 100
# RIP 85-543, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 107-691, alive count = 103
# RIP 103-655, alive count = 102
# RIP 72-428, alive count = 101
# RIP 93-602, alive count = 100
# RIP 87-561, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 105-676, alive count = 101
# RIP 93-604, alive count = 100
# RIP 86-555, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 86-557, alive count = 106
# RIP 90-593, alive count = 105
# RIP 105-686, alive count = 104
# RIP 105-684, alive count = 103
# RIP 104-673, alive count = 102
# RIP 109-698, alive count = 101
# RIP 90-592, alive count = 100
# RIP 87-566, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 83-510, alive count = 101
# RIP 95-633, alive count = 100
# RIP 97-643, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 105-685, alive count = 101
# RIP 105-680, alive count = 100
# RIP 103-651, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 95-622, alive count = 101
# RIP 105-682, alive count = 100
# RIP 104-675, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 109-700, alive count = 102
# RIP 93-610, alive count = 101
# RIP 114-714, alive count = 100
# RIP 107-688, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 105-683, alive count = 104
# RIP 51-273, alive count = 103
# RIP 95-629, alive count = 102
# RIP 117-718, alive count = 101
# RIP 109-703, alive count = 100
# RIP 95-626, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 70-391, alive count = 106
# RIP 97-642, alive count = 105
# RIP 125-725, alive count = 104
# RIP 92-599, alive count = 103
# RIP 90-586, alive count = 102
# RIP 107-694, alive count = 101
# RIP 125-723, alive count = 100
# RIP 117-716, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 103-658, alive count = 101
# RIP 109-705, alive count = 100
# RIP 113-710, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 107-693, alive count = 102
# RIP 103-653, alive count = 101
# RIP 139-734, alive count = 100
# RIP 51-271, alive count = 100
# RIP 113-711, alive count = 99
# Max population exceeded! Number of people to be killed: 6
# RIP 95-627, alive count = 105
# RIP 74-465, alive count = 104
# RIP 83-507, alive count = 103
# RIP 144-742, alive count = 102
# RIP 95-625, alive count = 101
# RIP 144-739, alive count = 100
# RIP 144-737, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 80-495, alive count = 103
# RIP 144-743, alive count = 102
# RIP 85-536, alive count = 101
# RIP 92-595, alive count = 100
# RIP 71-409, alive count = 100
# RIP 71-427, alive count = 100
# RIP 73-436, alive count = 98
# RIP 73-438, alive count = 98
# RIP 73-453, alive count = 98
# RIP 73-457, alive count = 98
# RIP 154-746, alive count = 94
# RIP 77-475, alive count = 100
# RIP 77-476, alive count = 100
# RIP 80-486, alive count = 98
# RIP 154-745, alive count = 97
# Max population exceeded! Number of people to be killed: 2
# RIP 87-575, alive count = 101
# RIP 110-707, alive count = 100
# RIP 82-502, alive count = 100
# RIP 83-506, alive count = 99
# RIP 84-523, alive count = 98
# RIP 84-535, alive count = 98
# RIP 164-756, alive count = 96
# RIP 85-540, alive count = 100
# RIP 85-541, alive count = 100
# RIP 86-554, alive count = 98
# RIP 87-562, alive count = 97
# RIP 87-572, alive count = 97
# RIP 87-577, alive count = 97
# RIP 87-582, alive count = 97
# RIP 87-583, alive count = 97
# RIP 90-589, alive count = 92
# RIP 90-590, alive count = 92
# RIP 90-591, alive count = 92
# RIP 92-597, alive count = 89
# RIP 92-598, alive count = 89
# RIP 92-600, alive count = 89
# RIP 93-608, alive count = 86
# RIP 170-757, alive count = 85
# RIP 95-624, alive count = 89
# RIP 95-631, alive count = 89
# RIP 95-632, alive count = 89
# RIP 170-762, alive count = 86
# RIP 97-637, alive count = 88
# RIP 97-638, alive count = 88
# RIP 97-639, alive count = 88
# RIP 97-641, alive count = 88
# RIP 97-644, alive count = 88
# RIP 98-647, alive count = 83
# RIP 103-649, alive count = 82
# RIP 103-652, alive count = 82
# RIP 103-659, alive count = 82
# RIP 103-660, alive count = 82
# RIP 104-661, alive count = 78
# RIP 104-662, alive count = 78
# RIP 104-663, alive count = 78
# RIP 104-664, alive count = 78
# RIP 104-665, alive count = 78
# RIP 104-666, alive count = 78
# RIP 104-667, alive count = 78
# RIP 104-668, alive count = 78
# RIP 104-669, alive count = 78
# RIP 104-670, alive count = 78
# RIP 104-671, alive count = 78
# RIP 104-672, alive count = 78
# RIP 104-674, alive count = 78
# RIP 105-677, alive count = 65
# RIP 105-679, alive count = 65
# RIP 107-687, alive count = 63
# RIP 107-689, alive count = 63
# RIP 107-690, alive count = 63
# RIP 107-692, alive count = 63
# RIP 117-719, alive count = 59
# RIP 109-695, alive count = 58
# RIP 109-696, alive count = 58
# RIP 109-697, alive count = 58
# RIP 109-699, alive count = 58
# RIP 109-701, alive count = 58
# RIP 109-702, alive count = 58
# RIP 109-704, alive count = 58
# RIP 110-706, alive count = 51
# RIP 110-708, alive count = 51
# RIP 113-709, alive count = 49
# RIP 114-712, alive count = 48
# RIP 114-713, alive count = 48
# RIP 114-715, alive count = 48
# RIP 117-717, alive count = 45
# RIP 117-720, alive count = 45
# RIP 117-721, alive count = 45
# RIP 154-749, alive count = 42
# RIP 125-722, alive count = 41
# RIP 125-724, alive count = 41
# RIP 125-726, alive count = 41
# RIP 125-727, alive count = 41
# RIP 125-728, alive count = 41
# RIP 125-729, alive count = 41
# RIP 127-730, alive count = 35
# RIP 127-731, alive count = 35
# RIP 127-732, alive count = 35
# RIP 139-733, alive count = 32
# RIP 139-735, alive count = 32
# RIP 139-736, alive count = 32
# RIP 144-738, alive count = 29
# RIP 144-740, alive count = 29
# RIP 144-741, alive count = 29
# RIP 144-744, alive count = 29
# RIP 154-747, alive count = 25
# RIP 154-748, alive count = 25
# RIP 170-760, alive count = 23
# RIP 164-750, alive count = 22
# RIP 164-751, alive count = 22
# RIP 164-752, alive count = 22
# RIP 164-753, alive count = 22
# RIP 164-754, alive count = 22
# RIP 164-755, alive count = 22
# RIP 183-769, alive count = 16
# RIP 170-758, alive count = 15
# RIP 170-759, alive count = 15
# RIP 170-761, alive count = 15
# RIP 174-763, alive count = 12
# RIP 174-764, alive count = 12
# RIP 174-765, alive count = 12
# RIP 174-766, alive count = 12
# RIP 174-767, alive count = 12
# RIP 183-768, alive count = 7
# RIP 183-770, alive count = 7
# RIP 183-771, alive count = 7
# RIP 183-772, alive count = 7
# RIP 186-773, alive count = 3
# RIP 186-774, alive count = 3
# RIP 186-775, alive count = 3

# %%
import os

os.system("say 'training complete'")
