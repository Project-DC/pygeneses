# %%
from pygeneses.hypertune import HyperTune

# %%
tuner = HyperTune(model_class="PrimaVita", hyperparameter="model_updates", values=[5, 10, 15, 20, 30, 50],
                  stop_at=2000)

# %%
tuner.hypertuner()
