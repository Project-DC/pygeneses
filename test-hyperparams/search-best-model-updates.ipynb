# %%
from pygeneses.hypertune import HyperTune
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
tuner = HyperTune(model_class="PrimaVita", hyperparameter="model_updates", values= [10, 50],
                  stop_at=2000)

# %%
tuner.hypertuner()
# Out:
# ----------------------------------------------------------------------------------------------------
# Model updates :  10
# ----------------------------------------------------------------------------------------------------
# RIP 0-0, alive count = 10
# RIP 0-5, alive count = 13
# RIP 0-6, alive count = 18
# RIP 0-2, alive count = 24
# RIP 0-8, alive count = 23
# RIP 10-12, alive count = 22
# RIP 10-13, alive count = 27
# RIP 10-14, alive count = 32
# RIP 10-15, alive count = 37
# RIP 10-17, alive count = 39
# RIP 10-18, alive count = 43
# RIP 10-23, alive count = 45
# RIP 10-26, alive count = 51
# RIP 10-22, alive count = 58
# RIP 20-28, alive count = 61
# RIP 20-29, alive count = 66
# RIP 20-30, alive count = 72
# RIP 20-33, alive count = 76
# RIP 20-35, alive count = 79
# RIP 20-36, alive count = 84
# RIP 20-38, alive count = 88
# RIP 20-40, alive count = 95
# RIP 20-42, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 30-96, alive count = 104
# ...
