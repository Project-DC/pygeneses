# %%
from pygeneses.hypertune import HyperTune
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
tuner = HyperTune(model_class="PrimaVita", hyperparameter="max_allowed_population", values=[100],
                  stop_at=2000)

# %%
tuner.hypertuner()
# Out:
# ----------------------------------------------------------------------------------------------------
# Max allowed population :  100
# ----------------------------------------------------------------------------------------------------
# RIP 0-9, alive count = 10
# RIP 0-5, alive count = 17
# RIP 0-7, alive count = 16
# RIP 0-8, alive count = 15
# RIP 10-10, alive count = 14
# RIP 10-11, alive count = 19
# RIP 10-12, alive count = 20
# RIP 10-13, alive count = 23
# RIP 10-15, alive count = 28
# RIP 0-4, alive count = 30
# RIP 0-2, alive count = 29
# RIP 0-3, alive count = 28
# RIP 20-18, alive count = 27
# RIP 20-19, alive count = 33
# RIP 20-22, alive count = 37
# RIP 20-23, alive count = 41
# RIP 20-24, alive count = 45
# RIP 20-26, alive count = 52
# RIP 20-28, alive count = 53
# RIP 20-29, alive count = 55
# RIP 20-31, alive count = 61
# RIP 20-32, alive count = 64
# RIP 20-34, alive count = 65
# RIP 20-36, alive count = 70
# RIP 20-37, alive count = 75
# ...
