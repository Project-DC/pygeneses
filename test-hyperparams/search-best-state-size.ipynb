# %%
from pygeneses.hypertune import HyperTune
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
tuner = HyperTune(model_class="PrimaVita", hyperparameter="state_size", values=[10,15,20,25,30,35,40,45,50],
                  stop_at=2000)

# %%
tuner.hypertuner()
# Out:
# ----------------------------------------------------------------------------------------------------
# State size :  10
# ----------------------------------------------------------------------------------------------------
# RIP 0-1, alive count = 10
# RIP 0-5, alive count = 12
# RIP 0-0, alive count = 17
# RIP 0-6, alive count = 16
# RIP 10-10, alive count = 15
# RIP 10-11, alive count = 19
# RIP 10-12, alive count = 26
# RIP 10-14, alive count = 29
# RIP 10-15, alive count = 32
# RIP 10-16, alive count = 38
# RIP 10-17, alive count = 42
# RIP 0-9, alive count = 46
# RIP 0-3, alive count = 45
# RIP 20-23, alive count = 49
# RIP 20-24, alive count = 51
# RIP 20-27, alive count = 56
# RIP 20-28, alive count = 57
# RIP 20-30, alive count = 63
# RIP 20-35, alive count = 67
# RIP 20-36, alive count = 73
# RIP 20-37, alive count = 77
# RIP 20-39, alive count = 79
# RIP 20-40, alive count = 85
# RIP 20-41, alive count = 86
# RIP 20-47, alive count = 89
# RIP 20-48, alive count = 91
# ...
