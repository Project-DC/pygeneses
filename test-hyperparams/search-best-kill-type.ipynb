# %%
from pygeneses.hypertune import HyperTune
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
tuner = HyperTune(model_class="PrimaVita", hyperparameter="kill_type", values=["difference", "random"], stop_at=2000)

# %%
tuner.hypertuner()
# Out:
# ----------------------------------------------------------------------------------------------------
# Kill type :  random
# ----------------------------------------------------------------------------------------------------
# RIP 0-0, alive count = 10
# RIP 10-11, alive count = 16
# RIP 10-12, alive count = 22
# RIP 10-14, alive count = 27
# RIP 10-15, alive count = 33
# RIP 10-16, alive count = 35
# RIP 20-17, alive count = 39
# RIP 20-18, alive count = 46
# RIP 20-19, alive count = 50
# RIP 20-20, alive count = 54
# RIP 20-21, alive count = 55
# RIP 20-22, alive count = 56
# RIP 20-24, alive count = 62
# RIP 20-25, alive count = 69
# RIP 20-27, alive count = 71
# RIP 20-28, alive count = 72
# RIP 20-29, alive count = 78
# RIP 20-30, alive count = 80
# RIP 20-32, alive count = 85
# RIP 20-34, alive count = 90
# RIP 20-35, alive count = 96
# Max population exceeded! Number of people to be killed: 56
# RIP 30-56, alive count = 100
# RIP 30-68, alive count = 99
# ...
