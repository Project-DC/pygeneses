# %%
from pygeneses.hypertune import HyperTune
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
tuner = HyperTune(model_class="PrimaVita", hyperparameter="max_age", values=[50, 90, 150, 250], stop_at=2000)

# %%
tuner.hypertuner()
# Out:
# ----------------------------------------------------------------------------------------------------
# Max age :  90
# ----------------------------------------------------------------------------------------------------
# RIP 0-9, alive count = 10
# RIP 0-1, alive count = 13
# RIP 0-7, alive count = 12
# RIP 20-17, alive count = 18
# RIP 20-18, alive count = 25
# RIP 0-2, alive count = 26
# RIP 0-8, alive count = 25
# RIP 30-21, alive count = 24
# RIP 30-23, alive count = 26
# RIP 30-24, alive count = 33
# RIP 30-25, alive count = 34
# RIP 30-27, alive count = 36
# RIP 30-28, alive count = 42
# RIP 20-16, alive count = 44
# RIP 20-19, alive count = 43
# RIP 10-13, alive count = 42
# RIP 10-12, alive count = 41
# RIP 40-34, alive count = 40
# RIP 40-37, alive count = 46
# RIP 40-38, alive count = 49
# RIP 40-39, alive count = 53
# RIP 40-40, alive count = 57
# RIP 40-41, alive count = 63
# RIP 40-43, alive count = 70
# RIP 40-44, alive count = 73
# RIP 40-45, alive count = 78
# ...
