# %%
from pygeneses.hypertune import HyperTune
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
tuner = HyperTune(model_class="PrimaVita", hyperparameter="max_age", values=[50, 100, 150, 200], stop_at=2000)

# %%
tuner.hypertuner()
# Out:
# ----------------------------------------------------------------------------------------------------
# Max age :  50
# ----------------------------------------------------------------------------------------------------
# RIP 0-9, alive count = 10
# RIP 0-1, alive count = 13
# RIP 0-3, alive count = 12
# RIP 10-10, alive count = 11
# RIP 10-13, alive count = 14
# RIP 10-11, alive count = 16
# RIP 0-6, alive count = 19
# RIP 0-8, alive count = 18
# RIP 20-14, alive count = 17
# RIP 20-18, alive count = 22
# RIP 20-19, alive count = 27
# RIP 0-0, alive count = 34
# RIP 20-15, alive count = 35
# RIP 21-23, alive count = 41
# RIP 0-7, alive count = 48
# RIP 30-25, alive count = 47
# RIP 30-32, alive count = 52
# RIP 30-33, alive count = 57
# RIP 30-34, alive count = 62
# RIP 30-35, alive count = 63
# RIP 30-36, alive count = 64
# RIP 30-39, alive count = 71
# RIP 30-41, alive count = 72
# RIP 30-44, alive count = 78
# RIP 20-16, alive count = 85
# RIP 31-45, alive count = 90
# ...
