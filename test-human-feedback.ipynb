# %% [markdown]
# # Train till stop_at 300

# %%
from pygeneses.envs.prima_vita import PrimaVita
# Out:
# pygame 2.0.0.dev10 (SDL 2.0.12, python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
params_dic = {"model_updates": 5}

model = PrimaVita(log_dir_info="new_loss", params_dic=params_dic, mode="human")

# %%
model.run(stop_at=300)
# Out:
# RIP 0-2, alive count = 10
# RIP 0-9, alive count = 12
# RIP 0-0, alive count = 17
# RIP 19-10, alive count = 22
# RIP 0-4, alive count = 24
# RIP 30-24, alive count = 28
# RIP 35-26, alive count = 34
# RIP 25-16, alive count = 35
# RIP 25-17, alive count = 41
# RIP 0-3, alive count = 48
# RIP 0-5, alive count = 53
# RIP 45-34, alive count = 60
# RIP 45-40, alive count = 66
# RIP 46-45, alive count = 69
# RIP 19-11, alive count = 72
# RIP 19-12, alive count = 77
# RIP 50-66, alive count = 81
# RIP 46-47, alive count = 88
# RIP 50-68, alive count = 94
# Max population exceeded! Number of people to be killed: 1
# RIP 50-63, alive count = 100
# RIP 35-25, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 46-48, alive count = 102
# RIP 57-84, alive count = 101
# RIP 45-38, alive count = 100
# RIP 50-57, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 63-121, alive count = 100
# RIP 50-69, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 0-8, alive count = 101
# RIP 63-124, alive count = 100
# RIP 57-82, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 49-50, alive count = 102
# RIP 50-70, alive count = 101
# RIP 59-87, alive count = 100
# RIP 59-88, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 61-106, alive count = 100
# RIP 59-89, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 45-36, alive count = 106
# RIP 55-71, alive count = 105
# RIP 61-108, alive count = 104
# RIP 61-107, alive count = 103
# RIP 49-49, alive count = 102
# RIP 69-138, alive count = 101
# RIP 63-126, alive count = 100
# RIP 25-13, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 61-110, alive count = 106
# RIP 59-91, alive count = 105
# RIP 49-52, alive count = 104
# RIP 63-122, alive count = 103
# RIP 25-18, alive count = 102
# RIP 45-32, alive count = 101
# RIP 50-59, alive count = 100
# RIP 49-53, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 67-130, alive count = 104
# RIP 45-37, alive count = 103
# RIP 70-145, alive count = 102
# RIP 70-156, alive count = 101
# RIP 59-96, alive count = 100
# RIP 56-80, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 60-100, alive count = 102
# RIP 62-118, alive count = 101
# RIP 67-132, alive count = 100
# RIP 59-86, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 59-95, alive count = 101
# RIP 30-21, alive count = 100
# RIP 59-92, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 60-101, alive count = 100
# RIP 46-42, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 70-152, alive count = 104
# RIP 46-43, alive count = 103
# RIP 61-109, alive count = 102
# RIP 62-114, alive count = 101
# RIP 59-93, alive count = 100
# RIP 56-81, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 55-75, alive count = 102
# RIP 69-139, alive count = 101
# RIP 30-19, alive count = 100
# RIP 61-105, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 70-163, alive count = 100
# RIP 45-30, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 70-161, alive count = 100
# RIP 63-120, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 57-83, alive count = 106
# RIP 70-164, alive count = 105
# RIP 75-179, alive count = 104
# RIP 50-67, alive count = 103
# RIP 0-7, alive count = 102
# RIP 69-137, alive count = 101
# RIP 50-60, alive count = 100
# RIP 63-128, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 55-77, alive count = 106
# RIP 71-176, alive count = 105
# RIP 69-133, alive count = 104
# RIP 71-168, alive count = 103
# RIP 70-157, alive count = 102
# RIP 59-90, alive count = 101
# RIP 46-46, alive count = 100
# RIP 45-35, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 57-85, alive count = 100
# RIP 59-94, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 70-150, alive count = 100
# RIP 70-153, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 79-198, alive count = 102
# RIP 45-29, alive count = 101
# RIP 70-165, alive count = 100
# RIP 70-160, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 71-167, alive count = 105
# RIP 75-184, alive count = 104
# RIP 60-103, alive count = 103
# RIP 75-194, alive count = 102
# RIP 70-154, alive count = 101
# RIP 70-158, alive count = 100
# RIP 30-22, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 75-187, alive count = 103
# RIP 50-58, alive count = 102
# RIP 50-61, alive count = 101
# RIP 55-76, alive count = 100
# RIP 70-148, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 56-78, alive count = 105
# RIP 80-209, alive count = 104
# RIP 45-33, alive count = 103
# RIP 70-151, alive count = 102
# RIP 69-134, alive count = 101
# RIP 80-202, alive count = 100
# RIP 71-175, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 71-177, alive count = 105
# RIP 81-215, alive count = 104
# RIP 69-135, alive count = 103
# RIP 75-190, alive count = 102
# RIP 67-131, alive count = 101
# RIP 63-127, alive count = 100
# RIP 71-172, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 62-116, alive count = 106
# RIP 60-104, alive count = 105
# RIP 81-225, alive count = 104
# RIP 75-188, alive count = 103
# RIP 81-221, alive count = 102
# RIP 71-166, alive count = 101
# RIP 80-205, alive count = 100
# RIP 75-193, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 85-236, alive count = 104
# RIP 62-112, alive count = 103
# RIP 70-155, alive count = 102
# RIP 75-195, alive count = 101
# RIP 85-242, alive count = 100
# RIP 45-31, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 81-220, alive count = 100
# RIP 62-115, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 81-228, alive count = 103
# RIP 85-235, alive count = 102
# RIP 70-144, alive count = 101
# RIP 49-51, alive count = 100
# RIP 71-174, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 49-55, alive count = 105
# RIP 81-222, alive count = 104
# RIP 85-230, alive count = 103
# RIP 76-196, alive count = 102
# RIP 80-201, alive count = 101
# RIP 56-79, alive count = 100
# RIP 75-180, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 81-224, alive count = 105
# RIP 81-223, alive count = 104
# RIP 81-217, alive count = 103
# RIP 75-178, alive count = 102
# RIP 71-173, alive count = 101
# RIP 86-247, alive count = 100
# RIP 0-1, alive count = 100
# RIP 0-6, alive count = 100
# RIP 50-62, alive count = 98
# Max population exceeded! Number of people to be killed: 4
# RIP 87-251, alive count = 103
# RIP 30-23, alive count = 102
# RIP 87-257, alive count = 101
# RIP 81-229, alive count = 100
# RIP 76-197, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 85-243, alive count = 102
# RIP 87-252, alive count = 101
# RIP 95-275, alive count = 100
# RIP 81-218, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 87-254, alive count = 103
# RIP 69-142, alive count = 102
# RIP 60-99, alive count = 101
# RIP 81-212, alive count = 100
# RIP 81-214, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 87-258, alive count = 103
# RIP 85-241, alive count = 102
# RIP 75-189, alive count = 101
# RIP 70-162, alive count = 100
# RIP 61-111, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 95-276, alive count = 103
# RIP 97-282, alive count = 102
# RIP 49-54, alive count = 101
# RIP 67-129, alive count = 100
# RIP 50-64, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 80-203, alive count = 105
# RIP 99-294, alive count = 104
# RIP 80-207, alive count = 103
# RIP 69-136, alive count = 102
# RIP 87-262, alive count = 101
# RIP 70-146, alive count = 100
# RIP 55-73, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 81-226, alive count = 103
# RIP 25-14, alive count = 102
# RIP 75-191, alive count = 101
# RIP 70-147, alive count = 100
# RIP 87-256, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 30-20, alive count = 101
# RIP 102-301, alive count = 100
# RIP 50-65, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 99-291, alive count = 104
# RIP 99-293, alive count = 103
# RIP 85-233, alive count = 102
# RIP 95-279, alive count = 101
# RIP 71-171, alive count = 100
# RIP 95-272, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 86-249, alive count = 106
# RIP 75-181, alive count = 105
# RIP 90-266, alive count = 104
# RIP 105-314, alive count = 103
# RIP 81-211, alive count = 102
# RIP 85-234, alive count = 101
# RIP 102-304, alive count = 100
# RIP 90-267, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 90-265, alive count = 100
# RIP 87-253, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 105-313, alive count = 103
# RIP 81-216, alive count = 102
# RIP 85-239, alive count = 101
# RIP 69-140, alive count = 100
# RIP 99-297, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 62-113, alive count = 102
# RIP 105-312, alive count = 101
# RIP 90-270, alive count = 100
# RIP 102-299, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 99-292, alive count = 101
# RIP 86-248, alive count = 100
# RIP 102-302, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 105-316, alive count = 100
# RIP 85-237, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 75-182, alive count = 104
# RIP 60-97, alive count = 103
# RIP 45-39, alive count = 102
# RIP 90-268, alive count = 101
# RIP 105-317, alive count = 100
# RIP 25-15, alive count = 100
# RIP 55-72, alive count = 99
# Max population exceeded! Number of people to be killed: 3
# RIP 112-334, alive count = 102
# RIP 102-305, alive count = 101
# RIP 75-185, alive count = 100
# RIP 95-277, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 87-255, alive count = 103
# RIP 86-250, alive count = 102
# RIP 85-240, alive count = 101
# RIP 108-323, alive count = 100
# RIP 99-295, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 95-278, alive count = 103
# RIP 112-332, alive count = 102
# RIP 97-281, alive count = 101
# RIP 80-206, alive count = 100
# RIP 102-300, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 115-357, alive count = 100
# RIP 49-56, alive count = 100
# RIP 87-261, alive count = 99
# Max population exceeded! Number of people to be killed: 6
# RIP 115-355, alive count = 105
# RIP 99-296, alive count = 104
# RIP 108-322, alive count = 103
# RIP 80-204, alive count = 102
# RIP 109-328, alive count = 101
# RIP 105-311, alive count = 100
# RIP 97-285, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 35-27, alive count = 103
# RIP 108-325, alive count = 102
# RIP 75-183, alive count = 101
# RIP 108-326, alive count = 100
# RIP 112-333, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 45-28, alive count = 101
# RIP 122-373, alive count = 100
# RIP 98-290, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 62-117, alive count = 105
# RIP 75-192, alive count = 104
# RIP 97-283, alive count = 103
# RIP 81-219, alive count = 102
# RIP 105-310, alive count = 101
# RIP 121-371, alive count = 100
# RIP 80-200, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 121-369, alive count = 104
# RIP 123-378, alive count = 103
# RIP 123-377, alive count = 102
# RIP 108-324, alive count = 101
# RIP 70-143, alive count = 100
# RIP 90-271, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 125-388, alive count = 103
# RIP 85-232, alive count = 102
# RIP 95-274, alive count = 101
# RIP 98-286, alive count = 100
# RIP 115-345, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 105-309, alive count = 104
# RIP 125-389, alive count = 103
# RIP 115-353, alive count = 102
# RIP 60-102, alive count = 101
# RIP 121-370, alive count = 100
# RIP 115-346, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 119-362, alive count = 103
# RIP 87-264, alive count = 102
# RIP 125-391, alive count = 101
# RIP 115-349, alive count = 100

# %%
from pygeneses.envs.prima_vita.env import save

# %%
save(model, "model-300")
# Out:
# Prima vita environment snapshot created successfully at model-300.vita!
