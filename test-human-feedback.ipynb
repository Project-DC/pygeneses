# %%
from pygeneses.envs.prima_vita import PrimaVita
# Out:
# pygame 2.0.0.dev10 (SDL 2.0.12, python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
params_dic = {"model_updates": 5, "initial_population": 10, "human_feedback": True}

model = PrimaVita(log_dir_info="break_asex", params_dic=params_dic)

# %%
model.run(stop_at=6000)
# Out:
# ----------------------------------------------------------------------------------------------------
# Index: 1
# Player at (737.88, 113.12)
# Player age: 0, energy: 200
# Player gender: Female
# Food #0 at (811.88, 126.12), distance = 75.13, direction = Down Left
# Food #1 at (808.88, 80.12), distance = 78.29, direction = Down Left
# Food #2 at (731.88, 179.12), distance = 66.27, direction = Down Left
# Action taken: Down Left
# Positive or negative (1 or -1): 1
# ----------------------------------------------------------------------------------------------------
# Index: 1
# Player at (737.88, 113.12)
# Player age: 1, energy: 198
# Player gender: Female
# Food #0 at (814.00, 124.00), distance = 76.89, direction = Down Left
# Food #1 at (811.00, 78.00), distance = 81.12, direction = Down Left
# Food #2 at (734.00, 177.00), distance = 64.00, direction = Down Left
# Action taken: Failed Ingestion
# Positive or negative (1 or -1): -1
# ...
