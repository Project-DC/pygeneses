# %%
from pygeneses.envs.prima_vita import PrimaVita
import time
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
rl_model = PrimaVita()

# %%
t1 = time.time()
rl_model.run(stop_at = 500)
print(time.time()-t1)
# Out:
# RIP 0-3, alive count = 10
# RIP 0-8, alive count = 11
# RIP 10-10, alive count = 12
# RIP 10-11, alive count = 13
# RIP 10-12, alive count = 20
# RIP 20-15, alive count = 27
# RIP 20-16, alive count = 32
# RIP 20-17, alive count = 39
# RIP 20-18, alive count = 41
# RIP 20-19, alive count = 42
# RIP 20-20, alive count = 46
# RIP 20-22, alive count = 49
# RIP 20-24, alive count = 56
# RIP 20-25, alive count = 62
# RIP 20-27, alive count = 63
# RIP 20-28, alive count = 70
# RIP 20-29, alive count = 71
# RIP 20-30, alive count = 75
# RIP 20-31, alive count = 76
# RIP 0-7, alive count = 78
# RIP 30-34, alive count = 83
# RIP 30-35, alive count = 84
# RIP 30-36, alive count = 89
# RIP 30-37, alive count = 95
# RIP 30-38, alive count = 96
# Max population exceeded! Number of people to be killed: 2
# RIP 40-116, alive count = 101
# RIP 40-112, alive count = 100
# RIP 30-40, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 30-70, alive count = 106
# ...
