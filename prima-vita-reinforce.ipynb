# %%
from pygeneses.envs.prima_vita import PrimaVita
# Out:
# pygame 2.0.0.dev10 (SDL 2.0.12, python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
rl_model = PrimaVita(log_dir_info="test_new_state_10k")

# %%
rl_model.run(stop_at=10000)
# Out:
# RIP 0-3, alive count = 10
# RIP 16-15, alive count = 16
# RIP 62-21, alive count = 22
# RIP 0-0, alive count = 26
# RIP 0-1, alive count = 26
# RIP 0-2, alive count = 26
# RIP 0-4, alive count = 26
# RIP 0-5, alive count = 26
# RIP 0-6, alive count = 26
# RIP 0-7, alive count = 26
# RIP 0-8, alive count = 26
# RIP 0-9, alive count = 26
# RIP 82-26, alive count = 17
# RIP 16-10, alive count = 19
# RIP 16-11, alive count = 19
# RIP 16-12, alive count = 19
# RIP 16-13, alive count = 19
# RIP 16-14, alive count = 19
# RIP 16-16, alive count = 19
# RIP 62-20, alive count = 13
# RIP 62-18, alive count = 17
# RIP 117-41, alive count = 21
# RIP 114-33, alive count = 25
# RIP 114-34, alive count = 32
# RIP 127-46, alive count = 37
# RIP 140-47, alive count = 41
# RIP 62-17, alive count = 47
# RIP 62-19, alive count = 47
# RIP 62-22, alive count = 47
# RIP 62-23, alive count = 47
# RIP 151-55, alive count = 43
# RIP 151-59, alive count = 48
# RIP 151-69, alive count = 55
# ...
