# %%
from pygeneses.envs.prima_vita.env import load
# Out:
# pygame 2.0.0.dev10 (SDL 2.0.12, python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
model = load("model-300")
# Out:
# Prima vita environment snapshot loaded successfully from model-300.vita!

# %%
model.run(stop_at=1000)
# Out:
# RIP 115-343, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 80-208, alive count = 102
# RIP 115-352, alive count = 101
# RIP 125-394, alive count = 100
# RIP 87-260, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 114-337, alive count = 106
# RIP 127-405, alive count = 105
# RIP 114-339, alive count = 104
# RIP 114-340, alive count = 103
# RIP 105-318, alive count = 102
# RIP 115-358, alive count = 101
# RIP 128-409, alive count = 100
# RIP 114-341, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 109-330, alive count = 100
# RIP 119-361, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 129-419, alive count = 100
# RIP 98-289, alive count = 100
# Max population exceeded! Number of people to be killed: 1
# RIP 128-412, alive count = 100
# RIP 105-319, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# ...
