# %%
from pygeneses.envs.prima_vita import PrimaVita
# Out:
# pygame 2.0.0.dev10 (SDL 2.0.12, python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
params_dic = {"model_updates": 10, "kill_type": "difference", "state_size": 22,
              "max_allowed_population": 100}

model = PrimaVita(log_dir_info="teach_ingestion", params_dic=params_dic, mode="human")

# %%
model.run(stop_at=6000)
# Out:
# Max population exceeded! Number of people to be killed: 1
# RIP 23-98, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 20-71, alive count = 104
# RIP 11-21, alive count = 103
# RIP 23-104, alive count = 102
# RIP 13-31, alive count = 101
# RIP 10-12, alive count = 100
# Max population exceeded! Number of people to be killed: 8
# RIP 0-1, alive count = 107
# RIP 13-32, alive count = 106
# RIP 23-102, alive count = 105
# RIP 15-48, alive count = 104
# RIP 22-81, alive count = 103
# RIP 14-41, alive count = 102
# RIP 23-90, alive count = 101
# RIP 17-59, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 23-88, alive count = 101
# RIP 14-40, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 20-66, alive count = 105
# RIP 12-25, alive count = 104
# RIP 0-0, alive count = 103
# RIP 0-5, alive count = 102
# RIP 18-62, alive count = 101
# RIP 22-74, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 24-107, alive count = 105
# RIP 24-111, alive count = 104
# RIP 12-26, alive count = 103
# RIP 24-119, alive count = 102
# RIP 14-43, alive count = 101
# RIP 11-20, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 15-45, alive count = 101
# RIP 16-55, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 22-82, alive count = 105
# RIP 23-89, alive count = 104
# RIP 22-75, alive count = 103
# RIP 16-52, alive count = 102
# RIP 12-24, alive count = 101
# RIP 24-109, alive count = 100
# Max population exceeded! Number of people to be killed: 8
# RIP 13-34, alive count = 107
# RIP 23-99, alive count = 106
# RIP 24-123, alive count = 105
# RIP 20-69, alive count = 104
# RIP 22-77, alive count = 103
# RIP 24-112, alive count = 102
# RIP 11-19, alive count = 101
# RIP 15-50, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 22-85, alive count = 102
# RIP 25-141, alive count = 101
# RIP 0-6, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 13-29, alive count = 102
# RIP 24-115, alive count = 101
# RIP 25-146, alive count = 100
# Max population exceeded! Number of people to be killed: 8
# RIP 15-46, alive count = 107
# RIP 23-91, alive count = 106
# RIP 23-96, alive count = 105
# RIP 0-8, alive count = 104
# RIP 23-100, alive count = 103
# RIP 25-128, alive count = 102
# RIP 13-30, alive count = 101
# RIP 26-151, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 11-17, alive count = 104
# RIP 25-134, alive count = 103
# RIP 23-94, alive count = 102
# RIP 20-68, alive count = 101
# RIP 10-13, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 25-140, alive count = 105
# RIP 10-14, alive count = 104
# RIP 26-161, alive count = 103
# RIP 25-133, alive count = 102
# RIP 26-163, alive count = 101
# RIP 20-65, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 25-147, alive count = 106
# RIP 26-169, alive count = 105
# RIP 24-126, alive count = 104
# RIP 26-173, alive count = 103
# RIP 22-79, alive count = 102
# RIP 26-174, alive count = 101
# RIP 13-38, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 24-106, alive count = 106
# RIP 26-150, alive count = 105
# RIP 26-158, alive count = 104
# RIP 26-157, alive count = 103
# RIP 0-7, alive count = 102
# RIP 23-87, alive count = 101
# RIP 13-37, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 18-61, alive count = 103
# RIP 20-67, alive count = 102
# RIP 26-159, alive count = 101
# RIP 25-132, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 27-187, alive count = 104
# RIP 11-16, alive count = 103
# RIP 11-23, alive count = 102
# RIP 26-170, alive count = 101
# RIP 14-42, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 13-33, alive count = 103
# RIP 23-93, alive count = 102
# RIP 25-139, alive count = 101
# RIP 26-154, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 27-197, alive count = 102
# RIP 10-10, alive count = 101
# RIP 27-198, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 27-184, alive count = 106
# RIP 24-110, alive count = 105
# RIP 26-172, alive count = 104
# RIP 26-180, alive count = 103
# RIP 15-44, alive count = 102
# RIP 18-60, alive count = 101
# RIP 22-72, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 25-130, alive count = 105
# RIP 24-116, alive count = 104
# RIP 23-95, alive count = 103
# RIP 16-51, alive count = 102
# RIP 17-57, alive count = 101
# RIP 0-9, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 28-213, alive count = 104
# RIP 25-138, alive count = 103
# RIP 26-165, alive count = 102
# RIP 26-178, alive count = 101
# RIP 26-164, alive count = 100
# Max population exceeded! Number of people to be killed: 8
# RIP 26-177, alive count = 107
# RIP 24-124, alive count = 106
# RIP 22-76, alive count = 105
# RIP 22-86, alive count = 104
# RIP 26-162, alive count = 103
# RIP 28-208, alive count = 102
# RIP 28-209, alive count = 101
# RIP 23-92, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 11-22, alive count = 105
# RIP 26-153, alive count = 104
# RIP 17-58, alive count = 103
# RIP 28-223, alive count = 102
# RIP 18-63, alive count = 101
# RIP 26-175, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 0-4, alive count = 102
# RIP 26-152, alive count = 101
# RIP 22-78, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 22-80, alive count = 103
# RIP 25-144, alive count = 102
# RIP 27-205, alive count = 101
# RIP 24-121, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 27-196, alive count = 103
# RIP 24-114, alive count = 102
# RIP 29-234, alive count = 101
# RIP 28-225, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 28-206, alive count = 106
# RIP 26-168, alive count = 105
# RIP 27-183, alive count = 104
# RIP 24-127, alive count = 103
# RIP 28-211, alive count = 102
# RIP 28-210, alive count = 101
# RIP 27-185, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 23-105, alive count = 102
# RIP 24-120, alive count = 101
# RIP 29-242, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 28-220, alive count = 104
# RIP 25-142, alive count = 103
# RIP 13-28, alive count = 102
# RIP 29-251, alive count = 101
# RIP 29-243, alive count = 100
