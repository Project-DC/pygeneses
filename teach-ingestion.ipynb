# %%
from pygeneses.envs.prima_vita import PrimaVita
# Out:
# pygame 2.0.0.dev10 (SDL 2.0.12, python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
params_dic = {"model_updates": 5, "kill_type": "fittest", "state_size": 22, "initial_energy": 500}

model = PrimaVita(log_dir_info="teach_ingestion", params_dic=params_dic, mode="human")

# %%
model.run(stop_at=6000)
# Out:
# Max population exceeded! Number of people to be killed: 1
# RIP 0-0, alive count = 100
# Max population exceeded! Number of people to be killed: 8
# RIP 0-1, alive count = 107
# RIP 0-2, alive count = 106
# RIP 0-3, alive count = 105
# RIP 0-4, alive count = 104
# RIP 0-5, alive count = 103
# RIP 0-6, alive count = 102
# RIP 0-8, alive count = 101
# RIP 0-9, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 10-10, alive count = 101
# RIP 10-11, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 10-12, alive count = 102
# RIP 10-13, alive count = 101
# RIP 10-14, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 10-15, alive count = 103
# RIP 10-16, alive count = 102
# RIP 11-17, alive count = 101
# RIP 11-18, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 11-19, alive count = 105
# RIP 11-20, alive count = 104
# RIP 11-21, alive count = 103
# RIP 0-7, alive count = 102
# RIP 11-22, alive count = 101
# RIP 11-23, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 12-24, alive count = 101
# RIP 12-25, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 12-26, alive count = 102
# RIP 12-27, alive count = 101
# RIP 13-28, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 13-29, alive count = 103
# RIP 13-30, alive count = 102
# RIP 14-31, alive count = 101
# RIP 14-32, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 14-33, alive count = 105
# RIP 14-34, alive count = 104
# RIP 14-35, alive count = 103
# RIP 14-36, alive count = 102
# RIP 14-37, alive count = 101
# RIP 14-38, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 16-39, alive count = 101
# RIP 16-40, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 16-41, alive count = 105
# RIP 17-42, alive count = 104
# RIP 17-43, alive count = 103
# RIP 17-44, alive count = 102
# RIP 17-45, alive count = 101
# RIP 17-46, alive count = 100
# Max population exceeded! Number of people to be killed: 8
# RIP 17-47, alive count = 107
# RIP 17-48, alive count = 106
# RIP 17-49, alive count = 105
# RIP 18-50, alive count = 104
# RIP 18-51, alive count = 103
# RIP 19-52, alive count = 102
# RIP 19-53, alive count = 101
# RIP 19-54, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 19-55, alive count = 105
# RIP 19-56, alive count = 104
# RIP 19-57, alive count = 103
# RIP 19-58, alive count = 102
# RIP 20-59, alive count = 101
# RIP 20-60, alive count = 100
# Max population exceeded! Number of people to be killed: 7
# RIP 20-61, alive count = 106
# RIP 20-62, alive count = 105
# RIP 20-63, alive count = 104
# RIP 20-64, alive count = 103
# RIP 20-65, alive count = 102
# RIP 20-66, alive count = 101
# RIP 20-67, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 20-68, alive count = 104
# RIP 20-69, alive count = 103
# RIP 20-70, alive count = 102
# RIP 20-71, alive count = 101
# RIP 20-72, alive count = 100
# Max population exceeded! Number of people to be killed: 4
# RIP 20-73, alive count = 103
# RIP 20-74, alive count = 102
# RIP 20-75, alive count = 101
# RIP 20-76, alive count = 100
# Max population exceeded! Number of people to be killed: 3
# RIP 20-77, alive count = 102
# RIP 20-78, alive count = 101
# RIP 20-79, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 20-80, alive count = 105
# RIP 20-81, alive count = 104
# RIP 20-82, alive count = 103
# RIP 20-83, alive count = 102
# RIP 21-84, alive count = 101
# RIP 21-85, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 21-86, alive count = 101
# RIP 21-87, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 21-88, alive count = 105
# RIP 21-89, alive count = 104
# RIP 21-90, alive count = 103
# RIP 21-91, alive count = 102
# RIP 21-92, alive count = 101
# RIP 21-93, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 21-94, alive count = 104
# RIP 21-95, alive count = 103
# RIP 21-96, alive count = 102
# RIP 21-97, alive count = 101
# RIP 21-98, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 21-99, alive count = 104
# RIP 21-100, alive count = 103
# RIP 21-101, alive count = 102
# RIP 21-102, alive count = 101
# RIP 21-103, alive count = 100
# Max population exceeded! Number of people to be killed: 8
# RIP 21-104, alive count = 107
# RIP 21-105, alive count = 106
# RIP 21-106, alive count = 105
# RIP 21-107, alive count = 104
# RIP 21-108, alive count = 103
# RIP 21-109, alive count = 102
# RIP 21-110, alive count = 101
# RIP 21-111, alive count = 100
# Max population exceeded! Number of people to be killed: 5
# RIP 21-112, alive count = 104
# RIP 21-113, alive count = 103
# RIP 21-114, alive count = 102
# RIP 21-115, alive count = 101
# RIP 21-116, alive count = 100
# Max population exceeded! Number of people to be killed: 2
# RIP 21-117, alive count = 101
# RIP 21-118, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 21-119, alive count = 105
# RIP 21-120, alive count = 104
# RIP 21-121, alive count = 103
# RIP 21-122, alive count = 102
# RIP 21-123, alive count = 101
# RIP 22-124, alive count = 100
# Max population exceeded! Number of people to be killed: 8
# RIP 22-125, alive count = 107
# RIP 22-126, alive count = 106
# RIP 22-127, alive count = 105
# RIP 22-128, alive count = 104
# RIP 23-129, alive count = 103
# RIP 23-130, alive count = 102
# RIP 23-131, alive count = 101
# RIP 23-132, alive count = 100
# Max population exceeded! Number of people to be killed: 6
# RIP 24-133, alive count = 105
# RIP 24-134, alive count = 104
# RIP 24-135, alive count = 103
# RIP 24-136, alive count = 102
# RIP 24-137, alive count = 101
# RIP 24-138, alive count = 100
